# %%
# !git clone https://github.com/Li-Chongyi/Zero-DCE.git
# Out:
# Cloning into 'Zero-DCE'...
# remote: Enumerating objects: 236, done.
# remote: Counting objects: 100% (236/236), done.
# remote: Compressing objects: 100% (189/189), done.
# remote: Total 236 (delta 43), reused 225 (delta 41), pack-reused 0
# Receiving objects: 100% (236/236), 30.89 MiB | 17.31 MiB/s, done.
# Resolving deltas: 100% (43/43), done.

# %%
! python /content/Zero-DCE/Zero-DCE_code/lowlight_train.py
# Out:
# 串流輸出內容已截斷至最後 5000 行。
# Loss at iteration 90: 0.45407578349113464
# Epoch [192/400], Loss at iteration 90: 0.45407578349113464
# Loss at iteration 100: 0.5422647595405579
# Epoch [192/400], Loss at iteration 100: 0.5422647595405579
# Loss at iteration 110: 0.5351215600967407
# Epoch [192/400], Loss at iteration 110: 0.5351215600967407
# Loss at iteration 120: 0.6367827653884888
# Epoch [192/400], Loss at iteration 120: 0.6367827653884888
# Loss at iteration 10: 0.6960859894752502
# Epoch [193/400], Loss at iteration 10: 0.6960859894752502
# Loss at iteration 20: 0.41369593143463135
# Epoch [193/400], Loss at iteration 20: 0.41369593143463135
# Loss at iteration 30: 0.3991207778453827
# Epoch [193/400], Loss at iteration 30: 0.3991207778453827
# Loss at iteration 40: 0.6395611763000488
# Epoch [193/400], Loss at iteration 40: 0.6395611763000488
# Loss at iteration 50: 0.5564043521881104
# Epoch [193/400], Loss at iteration 50: 0.5564043521881104
# ...

# %%
! python /content/Zero-DCE/Zero-DCE_code/lowlight_test.py
# Out:
# /content/Zero-DCE/Zero-DCE_code/data/test_data/LIME/2.bmp
# 0.2724919319152832
# /content/Zero-DCE/Zero-DCE_code/data/test_data/LIME/8.bmp
# 0.007068634033203125
# /content/Zero-DCE/Zero-DCE_code/data/test_data/LIME/1.bmp
# 0.008714675903320312
# /content/Zero-DCE/Zero-DCE_code/data/test_data/LIME/5.bmp
# 0.011298894882202148
# /content/Zero-DCE/Zero-DCE_code/data/test_data/LIME/10.bmp
# 0.00675654411315918
# /content/Zero-DCE/Zero-DCE_code/data/test_data/LIME/4.bmp
# 0.007193326950073242
# /content/Zero-DCE/Zero-DCE_code/data/test_data/LIME/3.bmp
# 0.006055355072021484
# /content/Zero-DCE/Zero-DCE_code/data/test_data/LIME/6.bmp
# 0.006252288818359375
# /content/Zero-DCE/Zero-DCE_code/data/test_data/LIME/9.bmp
# 0.006367683410644531
# /content/Zero-DCE/Zero-DCE_code/data/test_data/LIME/7.bmp
# 0.006075143814086914
# /content/Zero-DCE/Zero-DCE_code/data/test_data/DICM/47.jpg
# 0.006361484527587891
# /content/Zero-DCE/Zero-DCE_code/data/test_data/DICM/42.jpg
# 0.0063855648040771484
# ...
